# %%
import string
import collections
 
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from pprint import pprint
 
 
def process_text(text, stem=True):
    """ Tokenize text and stem words removing punctuation """
    transtable = {ord(s):None for s in string.punctuation}
    transtable[ord('/')] = u' '
    text = text.translate(transtable)
    tokens = word_tokenize(text)
 
    if stem:
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(t) for t in tokens]
 
    return tokens
 
 
def cluster_texts(texts, clusters=10):
    """ Transform texts to Tf-Idf coordinates and cluster texts using K-Means """
    vectorizer = TfidfVectorizer(tokenizer=process_text,
                                 stop_words=stopwords.words('english'),
                                 max_df=0.9,
                                 min_df=0.2,
                                 lowercase=True)
 
    tfidf_model = vectorizer.fit_transform(texts)
    km_model = KMeans(n_clusters=clusters)
    km_model.fit(tfidf_model)
    
    order_centroids = km_model.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names()
    for i in range(clusters):
        print('Cluster %d:' % i)
    for ind in order_centroids[i, :10]:
        print('%s' % terms[ind])
 
    clustering = collections.defaultdict(list)
 
    for idx, label in enumerate(km_model.labels_):
        clustering[label].append(idx)
 
    return clustering

# %% [markdown]
# http://stackoverflow.com/questions/23175809/typeerror-translate-takes-one-argument-2-given-python

# %%
process_text(" To$kenize text/removing pu&nctua^tion ",stem=False)
# Out:
# ['Tokenize', 'text', 'removing', 'punctuation']

# %%
import pandas as pd

data = pd.read_csv('../Jobsnew.csv',delimiter='\t',encoding='latin-1')

# %%
texts = data.abstract.tolist()

# %%
type(texts)
# Out:
# list

# %%
tokenisedtext = [process_text(str(text)) for text in texts]

# %%
tokenisedtext
# Out:
# [['We',
#   'are',
#   'look',
#   'for',
#   'suitabl',
#   'applic',
#   'to',
#   'fill',
#   'the',
#   'posit',
#   'of',
#   'Delicatessen',
#   'Assist',
#   'Manag',
#   'and',
#   'Delicatessen',
#   'Supervisor',
#   'at',
#   'our',
#   'Edmonton',
#   'store',
#   'The',
#   'applic',
#   'must',
#   'have',
#   'at',
#   'least',
#   '1',
#   'year',
#   'manag',
#   'supervisori',
#   'experi',
#   'in',
#   'a',
#   'larg',
#   'Delicatessen',
#   'Depart',
#   'includ',
#   'strong',
#   'team',
#   'leadership',
#   'qualiti'],
#  ['Bricki',
#   'Labour',
#   'requir',
#   'for',
#   'a',
#   'small',
#   'team',
#   'work',
#   'with',
#   'the',
#   'owner',
#   'A',
#   'good',
#   'environ',
#   'where',
#   'we',
#   'are',
#   'happi',
#   'to',
#   'guid',
#   'and',
#   'teach',
#   'our',
#   'labour',
#   'All',
#   'our',
#   'Bricklay',
#   'have',
#   'first',
#   'been',
#   'labour',
#   'and',
#   'treat',
#   'them',
#   'well',
#   'Must',
#   'have',
#   'a',
#   'white',
#   'card',
#   'ABN',
#   'work',
#   'boot',
#   'and',
#   'some',
#   'experi',
#   'To',
#   'discuss',
#   'the',
#   'posit',
#   'call',
#   'or',
#   'text',
#   'Megan',
#   'on',
#   '6344',
#   'click',
#   'to',
#   'reveal',
#   'or',
#   'Mark',
#   '6344',
#   'click',
#   'to',
#   'reveal'],
#  ['We',
#   'are',
#   'look',
#   'for',
#   'someon',
#   'to',
#   'take',
#   'up',
#   'to',
#   'the',
#   'next',
#   'level',
#   'and',
#   'who',
#   'ha',
#   'previous',
#   'work',
#   'as',
#   'a',
#   'Head',
#   'Chef',
#   'in',
#   'a',
#   'pub',
#   'environ',
#   'You',
#   'will',
#   'have',
#   'a',
#   'strong',
#   'passion',
#   'for',
#   'produc',
#   'amaz',
#   'pub',
#   'grub',
#   'with',
#   'present',
#   'to',
#   'match'],
#  ['We',
#   'are',
#   'seek',
#   'experienc',
#   'conveyanc',
#   'settlement',
#   'clerk',
#   'who',
#   'are',
#   'keen',
#   'to',
#   'take',
#   'on',
#   'a',
#   'new',
#   'challeng',
#   'in',
#   'their',
#   'career',
#   'Step',
#   'away',
#   'from',
#   'file',
#   'manag',
#   'complet',
#   'you',
#   'will',
#   'have',
#   'the',
#   'opportun',
#   'to',
#   'use',
#   'your',
#   'peopl',
#   'skill',
#   'to',
#   'hit',
#   'the',
#   'road',
#   'and',
#   'build',
#   'relationship',
#   'with',
#   'a',
#   'number',
#   'of',
#   'other',
#   'profession',
#   'in',
#   'the',
#   'industri'],
#  ['Thi',
#   'is',
#   'fundament',
#   'a',
#   'nut',
#   'and',
#   'bolt',
#   'role',
#   'that',
#   'would',
#   'suit',
#   'a',
#   'systemat',
#   'driven',
#   'individu',
#   'who',
#   'strive',
#   'on',
#   'logist',
#   'and',
#   'organis',
#   'Report',
#   'to',
#   'the',
#   'GM',
#   'of',
#   'the',
#   'venu',
#   'the',
#   'day',
#   'to',
#   'day',
#   'duti',
#   'will',
#   'requir',
#   'an',
#   'analyt',
#   'mind',
#   'someon',
#   'who',
#   'also',
#   'thrive',
#   'on',
#   'plan',
#   'and',
#   'troubleshoot',
#   'With',
#   'the',
#   'abil',
#   'to',
#   'multitask',
#   'and',
#   'work',
#   'within',
#   'a',
#   'tight',
#   'timefram',
#   'you',
#   'will',
#   'be',
#   'someon',
#   'who',
#   'is',
#   'ultim',
#   'highli',
#   'motiv',
#   'and',
#   'love',
#   'challeng'],
#  ['Due',
#   'to',
#   'an',
#   'intern',
#   'promot',
#   'our',
#   'client',
#   'a',
#   'wellestablish',
#   'organis',
#   'within',
#   'the',
#   'construct',
#   'industri',
#   'is',
#   'current',
#   'seek',
#   'an',
#   'experienc',
#   'Transport',
#   'Schedul',
#   'Coordin',
#   'from',
#   'the',
#   'Construct',
#   'Concret',
#   'Industri',
#   'to',
#   'join',
#   'their',
#   'team',
#   'on',
#   'a',
#   'perman',
#   'full',
#   'time',
#   'basi'],
#  ['nan'],
#  ['Due',
#   'to',
#   'demand',
#   'the',
#   'compani',
#   'ha',
#   'an',
#   'amaz',
#   'opportun',
#   'for',
#   'an',
#   'experi',
#   'Bar',
#   'Supervisor',
#   'look',
#   'to',
#   'take',
#   'the',
#   'next',
#   'step',
#   'in',
#   'their',
#   'career',
#   'Locat',
#   'in',
#   'one',
#   'of',
#   'Sydney',
#   'premier',
#   'and',
#   'busiest',
#   'indoor',
#   'outdoor',
#   'waterfront',
#   'locat',
#   'and',
#   'part',
#   'of',
#   'a',
#   'lead',
#   'hospit',
#   'group',
#   'which',
#   'boast',
#   'multipl',
#   'venu',
#   'thi',
#   'opportun',
#   'will',
#   'not',
#   'last',
#   'long'],
#  ['If',
#   'you',
#   'are',
#   'someon',
#   'that',
#   'strive',
#   'to',
#   'put',
#   'a',
#   'smile',
#   'on',
#   'a',
#   'resid',
#   'face',
#   'make',
#   'a',
#   'real',
#   'differ',
#   'to',
#   'their',
#   'qualiti',
#   'of',
#   'life',
#   'make',
#   'the',
#   'most',
#   'of',
#   'your',
#   'passion',
#   'by',
#   'join',
#   'us',
#   'at',
#   'UnitingCar',
#   'Age',
#   'NSWACT',
#   'We',
#   'are',
#   'keen',
#   'to',
#   'provid',
#   'you',
#   'with',
#   'a',
#   'platform',
#   'to',
#   'shineWHO',
#   'WE',
#   'AREUnitingCar',
#   'Age',
#   'NSWACT',
#   'the',
#   'age',
#   'care',
#   'ministri',
#   'of',
#   'the',
#   'Unit',
#   'Church',
#   'a',
#   'Servic',
#   'Group',
#   'of',
#   'UnitingCar',
#   'NSWACT',
#   'is',
#   'the',
#   'singl',
#   'largest',
#   'notforprofit',
#   'provid',
#   'of',
#   'age',
#   'care',
#   'servic',
#   'in',
#   'NSW',
#   'the',
#   'ACT',
#   'We',
#   'are',
#   'an',
#   'industri',
#   'leaderEveryday',
#   'ha',
#   'mean',
#   'when',
#   'you',
#   'work',
#   'for',
#   'us',
#   'Your',
#   'work',
#   'make',
#   'a',
#   'real',
#   'differenceBi',
#   'enrich',
#   'the',
#   'live',
#   'of',
#   'those',
#   'we',
#   'serv',
#   'we',
#   'add',
#   'valu',
#   'to',
#   'the',
#   'experi',
#   'of',
#   'life',
#   'As',
#   'an',
#   'Industri',
#   'Leader',
#   'we',
#   'valu',
#   'our',
#   'staff',
#   'and',
#   'our',
#   'client',
#   'We',
#   'are',
#   'bold',
#   'imagin',
#   'respect',
#   'and',
#   'compassion',
#   'becaus',
#   'that',
#   'is',
#   'what',
#   'give',
#   'us',
#   'the',
#   'edg',
#   'and',
#   'satisfact',
#   'in',
#   'what',
#   'we',
#   'doJOIN',
#   'OUR',
#   'DYNAM',
#   'TEAMMirinjani',
#   'is',
#   'now',
#   'seek',
#   'dedic',
#   'Care',
#   'Servic',
#   'Employe',
#   'to',
#   'join',
#   'their',
#   'dynam',
#   'team',
#   'in',
#   'Weston',
#   'ACT',
#   'on',
#   'a',
#   'casual',
#   'basi',
#   'Success',
#   'candid',
#   'will',
#   'be',
#   'requir',
#   'to',
#   'work',
#   'across',
#   'all',
#   'support',
#   'streamsW',
#   'want',
#   'a',
#   'care',
#   'worker',
#   'who',
#   'is',
#   'passion',
#   'genuin',
#   'and',
#   'commit',
#   'to',
#   'provid',
#   'except',
#   'care',
#   'You',
#   'will',
#   'work',
#   'collabor',
#   'as',
#   'a',
#   'care',
#   'team',
#   'member',
#   'to',
#   'deliv',
#   'a',
#   'personcentr',
#   'care',
#   'that',
#   'enhanc',
#   'the',
#   'resid',
#   'wellb',
#   'and',
#   'is',
#   'inclus',
#   'of',
#   'their',
#   'physic',
#   'psycholog',
#   'social',
#   'and',
#   'spiritu',
#   'qualiti',
#   'in',
#   'order',
#   'to',
#   'facilit',
#   'selfdetermin',
#   'capac',
#   'and',
#   'resili',
#   'as',
#   'well',
#   'as',
#   'improv',
#   'social',
#   'engag',
#   'and',
#   'qualiti',
#   'of',
#   'life',
#   'for',
#   'the',
#   'resid',
#   'and',
#   'to',
#   'incorpor',
#   'the',
#   'deliveri',
#   'of',
#   'person',
#   'hygien',
#   'nutrit',
#   'and',
#   'hydrat',
#   'contin',
#   'care',
#   'and',
#   'leisur',
#   'and',
#   'lifestyl',
#   'activitiesTo',
#   'succeed',
#   'in',
#   'thi',
#   'role',
#   'you',
#   'will',
#   'meet',
#   'the',
#   'criteria',
#   'belowEssenti',
#   'Criteria',
#   'Demonstr',
#   'a',
#   'genuin',
#   'interest',
#   'in',
#   'Age',
#   'Care',
#   'Nurs',
#   'Strong',
#   'commun',
#   'and',
#   'interperson',
#   'skill',
#   'particularli',
#   'with',
#   'age',
#   'person',
#   'rel',
#   'and',
#   'other',
#   'health',
#   'profession',
#   'Knowledg',
#   'and',
#   'understand',
#   'of',
#   'Work',
#   'Health',
#   'and',
#   'Safeti',
#   'WH',
#   'and',
#   'risk',
#   'manag',
#   'practic',
#   'Abil',
#   'to',
#   'work',
#   'in',
#   'a',
#   'team',
#   'environ',
#   'or',
#   'independ',
#   'Abil',
#   'to',
#   'be',
#   'proactiv',
#   'flexibl',
#   'and',
#   'take',
#   'initi',
#   'in',
#   'the',
#   'work',
#   'environ',
#   'Commit',
#   'to',
#   'ongo',
#   'profession',
#   'developmentDesir',
#   'Criteria',
#   'An',
#   'awar',
#   'of',
#   'the',
#   'Age',
#   'Care',
#   'Accredit',
#   'Process',
#   'Previou',
#   'experi',
#   'in',
#   'age',
#   'care',
#   'person',
#   'care',
#   'work',
#   'Basic',
#   'comput',
#   'literaci',
#   'Certif',
#   'III',
#   'in',
#   'Age',
#   'Care',
#   'Work',
#   'Commun',
#   'Servic',
#   'or',
#   'equival',
#   'Current',
#   'First',
#   'Aid',
#   'CertificateApplic',
#   'must',
#   'be',
#   'in',
#   'a',
#   'posit',
#   'to',
#   'demonstr',
#   'the',
#   'valu',
#   'of',
#   'UnitingCar',
#   'have',
#   'a',
#   'high',
#   'level',
#   'of',
#   'person',
#   'integr',
#   'and',
#   'a',
#   'willing',
#   'to',
#   'work',
#   'within',
#   'the',
#   'etho',
#   'of',
#   'the',
#   'Unit',
#   'ChurchTO',
#   'APPLi',
#   'NOW',
#   'Pleas',
#   'visit',
#   'our',
#   'career',
#   'page',
#   'http',
#   'wwwunitingorg',
#   'joinourteam',
#   'currentvacanciesFor',
#   'Further',
#   'Inform',
#   'ContactGraem',
#   'Barn',
#   'on',
#   '02',
#   '6288',
#   '4300If',
#   'you',
#   'requir',
#   'assist',
#   'with',
#   'your',
#   'applic',
#   'pleas',
#   'contact',
#   'HR',
#   'Servic',
#   'on',
#   '1300',
#   '797',
#   '358Close',
#   'Date',
#   '5pm',
#   'on',
#   '15',
#   'Januari',
#   '2016UnitingCar',
#   'is',
#   'proud',
#   'to',
#   'be',
#   'an',
#   'EEO',
#   'employ',
#   'UnitingCar',
#   'support',
#   'an',
#   'inclus',
#   'approach',
#   'in',
#   'the',
#   'workplac',
#   'We',
#   'celebr',
#   'our',
#   'divers',
#   'and',
#   'welcom',
#   'staff',
#   'regardless',
#   'of',
#   'ethnic',
#   'faith',
#   'sexual',
#   'orient',
#   'gender',
#   'ident',
#   'and',
#   'lifestyl',
#   'choic',
#   'Aborigin',
#   'and',
#   'Torr',
#   'Strait',
#   'Island',
#   'peopl',
#   'are',
#   'encourag',
#   'to',
#   'applyAppoint',
#   'will',
#   'be',
#   'condit',
#   'upon',
#   'a',
#   'satisfactori',
#   'Feder',
#   'Crimin',
#   'Record',
#   'Check'],
#  ['We',
#   'are',
#   'look',
#   'for',
#   'construct',
#   'gener',
#   'labour',
#   'for',
#   'work',
#   'throughout',
#   'Sydney',
#   'You',
#   'will',
#   'need',
#   'to',
#   'be',
#   'energet',
#   'have',
#   'a',
#   'great',
#   'attitud',
#   'be',
#   'fit',
#   'and',
#   'abl',
#   'Our',
#   'labour',
#   'work',
#   'includ',
#   'but',
#   'is',
#   'not',
#   'limit',
#   'to',
#   'construct',
#   'site',
#   'landscap',
#   'gener',
#   'labour',
#   'role',
#   'These',
#   'are',
#   'ongo',
#   'labour',
#   'role',
#   'and',
#   'highli',
#   'sort',
#   'after',
#   'onli',
#   'resum',
#   'that',
#   'match',
#   'the',
#   'below',
#   'criteria',
#   'will',
#   'be',
#   'accept',
#   '23',
#   '28',
#   'per',
#   'hour'],
#  ['nan'],
#  ['We',
#   'are',
#   'a',
#   'build',
#   'restor',
#   'compani',
#   'seek',
#   'demolit',
#   'worker',
#   'to',
#   'work',
#   'full',
#   'time',
#   'with',
#   'our',
#   'grow',
#   'compani',
#   'We',
#   'have',
#   'a',
#   'major',
#   'job',
#   'start',
#   'veri',
#   'soon',
#   'and',
#   'requir',
#   'addit',
#   'labour'],
#  ['We',
#   'arelook',
#   'for',
#   'a',
#   'full',
#   'time',
#   'cook',
#   'chef',
#   'that',
#   'will',
#   'help',
#   'our',
#   'head',
#   'chef',
#   'execut',
#   'ourcurr',
#   'menu',
#   'to',
#   'a',
#   'new',
#   'level',
#   'of',
#   'café',
#   'sophist',
#   'With',
#   'our',
#   'newey',
#   'catch',
#   'interior',
#   'most',
#   'advanc',
#   'cook',
#   'equip',
#   'we',
#   'are',
#   'all',
#   'aboutth',
#   'best',
#   'cafe',
#   'experi',
#   'with',
#   'fast',
#   'healthi',
#   'qualiti',
#   'food',
#   'in',
#   'a',
#   'comfort',
#   'casual',
#   'surround'],
#  ['A',
#   'fantast',
#   'opportun',
#   'exist',
#   'for',
#   'the',
#   'right',
#   'candid',
#   'to',
#   'join',
#   'our',
#   'busi',
#   'wellestablish',
#   'and',
#   'highli',
#   'reput',
#   'practic',
#   'Our',
#   'practic',
#   'wa',
#   'establish',
#   'in',
#   '2005',
#   'and',
#   'ha',
#   'a',
#   'great',
#   'reput',
#   'in',
#   'the',
#   'commun',
#   'and',
#   'amongst',
#   'health',
#   'profession'],
#  ['We',
#   'have',
#   'a',
#   'great',
#   'team',
#   'but',
#   'we',
#   'are',
#   'one',
#   'short',
#   'We',
#   'are',
#   'look',
#   'for',
#   'a',
#   'parttim',
#   'cook',
#   'chef',
#   'apprentic',
#   'chef',
#   'that',
#   'can',
#   'help',
#   'out',
#   'in',
#   'our',
#   'fast',
#   'becom',
#   'busi',
#   'kitchen',
#   'Our',
#   'chef',
#   'ha',
#   'develop',
#   'a',
#   'great',
#   'excit',
#   'menu',
#   'that',
#   'you',
#   'can',
#   'be',
#   'proud',
#   'of'],
#  ['Our',
#   'client',
#   'is',
#   'a',
#   'major',
#   'onlin',
#   'retail',
#   'base',
#   'in',
#   'Derrimut',
#   'Melbourn',
#   'Current',
#   'they',
#   'requir',
#   'an',
#   'experienc',
#   'Store',
#   'person',
#   'to',
#   'receiv',
#   'and',
#   'dispatch',
#   'good',
#   'within',
#   'the',
#   'warehous'],
#  ['Red',
#   'Rock',
#   'Asian',
#   'Street',
#   'Food',
#   'at',
#   'Oxenford',
#   'Requir',
#   'full',
#   'time',
#   'Wok',
#   'Cook',
#   'for',
#   'fast',
#   'pace',
#   'casual',
#   'dine',
#   'restaur',
#   'Thi',
#   'is',
#   'your',
#   'opportun',
#   'to',
#   'bring',
#   'your',
#   'creativ',
#   'and',
#   'profession',
#   'To',
#   'work',
#   'for',
#   'a',
#   'fast',
#   'food',
#   'restaur',
#   'which',
#   'is',
#   'identifi',
#   'for',
#   'deliv',
#   'a',
#   'servic',
#   'of',
#   'excel',
#   'at',
#   'all',
#   'time',
#   'You',
#   'will',
#   'be',
#   'offer',
#   'ongo',
#   'train',
#   'as',
#   'well',
#   'as',
#   'career',
#   'develop',
#   'and',
#   'satisfact',
#   'while',
#   'be',
#   'a',
#   'valu',
#   'team',
#   'member',
#   'for',
#   'a',
#   'recognis',
#   'fast',
#   'food',
#   'restaur',
#   'Pleas',
#   'send',
#   'a',
#   'resum',
#   'to',
#   'breau',
#   'click',
#   'to',
#   'reveal'],
#  ['Thank',
#   'you',
#   'for',
#   'your',
#   'interest',
#   'in',
#   'the',
#   'Enrol',
#   'Nurs',
#   'En',
#   'role',
#   'Whilst',
#   'option',
#   'we',
#   'recommend',
#   'enter',
#   'your',
#   'inform',
#   'below',
#   'to',
#   'assist',
#   'the',
#   'applic',
#   'process',
#   'By',
#   'do',
#   'so',
#   'you',
#   'agre',
#   'to',
#   'CareerOn',
#   'contact',
#   'you',
#   'regard',
#   'thi',
#   'and',
#   'similar',
#   'job',
#   'offer',
#   'and',
#   'CareerOn',
#   'site',
#   'and',
#   'career',
#   'news',
#   'You',
#   'also',
#   'consent',
#   'to',
#   'CareerOn',
#   'provid',
#   'your',
#   'email',
#   'address',
#   'to',
#   'the',
#   'employ',
#   'recruit',
#   'advertis',
#   'thi',
#   'job',
#   'who',
#   'may',
#   'contact',
#   'you',
#   'directli',
#   'regard',
#   'your',
#   'applic',
#   'even',
#   'if',
#   'not',
#   'complet'],
#  ['Look',
#   'for',
#   'immedi',
#   'start',
#   'of',
#   'onli',
#   '2',
#   'Experienc',
#   'cleaner',
#   'for',
#   'vacant',
#   'hous',
#   'MUST',
#   'H',
#   'AVE',
#   'YOUR',
#   'O',
#   'WN',
#   'TRANSPORT',
#   'And',
#   'AUSTALIAN',
#   'DRIVER',
#   'LICENC',
#   'ESSENTI',
#   'pleas',
#   'DONT',
#   'APPLi',
#   'IF',
#   'NOT',
#   'EXPERIENC',
#   'Approx',
#   '2',
#   '3',
#   'week',
#   'if',
#   'u',
#   'r',
#   'ok',
#   '24',
#   'a',
#   'hour',
#   'Immedi',
#   'start',
#   'TEXT',
#   'ONLi',
#   'with',
#   'name',
#   'Experi',
#   'and',
#   'onli',
#   'if',
#   'u',
#   'have',
#   'transport',
#   'and',
#   'Australian',
#   'ID',
#   'Thank'],
#  ['Attract',
#   'salari',
#   'packag',
#   'balanc',
#   'five',
#   'day',
#   'roster',
#   'with',
#   'no',
#   'split',
#   'shift',
#   '2',
#   'day',
#   'off',
#   'in',
#   'a',
#   'row',
#   'thi',
#   'is',
#   'a',
#   'great',
#   'opportunityAppli',
#   'now',
#   'To',
#   'appli',
#   'onlin',
#   'pleas',
#   'click',
#   'on',
#   'the',
#   'appropri',
#   'link',
#   'below',
#   'Altern',
#   'for',
#   'a',
#   'confidenti',
#   'discuss',
#   'pleas',
#   'contact',
#   'Sian',
#   'Foster',
#   'on',
#   '02',
#   '4980',
#   'click',
#   'to',
#   'reveal'],
#  ['Work',
#   'with',
#   'the',
#   'group',
#   'Execut',
#   'Chef',
#   'thi',
#   'role',
#   'is',
#   'integr',
#   'in',
#   'provid',
#   'a',
#   'seamless',
#   'intergr',
#   'between',
#   'Breakfast',
#   'Lunch',
#   'and',
#   'dinner',
#   'and',
#   'the',
#   'ongo',
#   'success',
#   'of',
#   'the',
#   'venu',
#   'as',
#   'a',
#   'whole'],
#  ['Enquiri',
#   'can',
#   'be',
#   'direct',
#   'to',
#   'Paul',
#   'Heali',
#   'Group',
#   'Manag',
#   'Asset',
#   'Infrastructur',
#   'on',
#   '0417',
#   '509',
#   '732',
#   'Applic',
#   'close',
#   'at',
#   '2',
#   'pm',
#   'Friday',
#   '8',
#   'Januari',
#   '2016'],
#  ['LOVE',
#   'to',
#   'lead',
#   'andinspir',
#   'team',
#   'Noth',
#   'excit',
#   'you',
#   'more',
#   'than',
#   'except',
#   'servic',
#   'deliveri',
#   'withcustom',
#   'Obsess',
#   'with',
#   'stationeri',
#   'like',
#   'the',
#   'latest',
#   'pen',
#   'that',
#   'rub',
#   'out',
#   'mistakesGet',
#   'a',
#   'buzz',
#   'from',
#   'the',
#   'latest',
#   'technolog',
#   'and',
#   'enjoy',
#   'discuss',
#   'it',
#   'functionalitiesor',
#   'do',
#   'love',
#   'arrang',
#   'custom',
#   'next',
#   'offic',
#   'setup',
#   'with',
#   'all',
#   'the',
#   'goodi',
#   'OFFICEWORKSHA',
#   'WHAT',
#   'YOU',
#   'ARE',
#   'LOOK',
#   'FOR'],
#  ['If',
#   'your',
#   'look',
#   'for',
#   'work',
#   'youv',
#   'come',
#   'to',
#   'the',
#   'right',
#   'place',
#   'Zoom',
#   'Recruit',
#   'Train',
#   'offer',
#   'temporari',
#   'and',
#   'perman',
#   'placement',
#   'servic',
#   'in',
#   'variou',
#   'industri',
#   'sector',
#   'and',
#   'can',
#   'help',
#   'you',
#   'find',
#   'you',
#   'your',
#   'next',
#   'dream',
#   'job',
#   'Your',
#   'work',
#   'experi',
#   'and',
#   'skill',
#   'are',
#   'veri',
#   'import',
#   'to',
#   'us',
#   'so',
#   'make',
#   'sure',
#   'you',
#   'give',
#   'yourself',
#   'the',
#   'best',
#   'chanc',
#   'in',
#   'gain',
#   'the',
#   'right',
#   'posit',
#   'for',
#   'you',
#   'An',
#   'updat',
#   'resum',
#   'with',
#   'all',
#   'the',
#   'relev',
#   'previou',
#   'work',
#   'inform',
#   'is',
#   'realli',
#   'import',
#   'Dont',
#   'forget',
#   'to',
#   'includ',
#   'all',
#   'your',
#   'relev',
#   'ticket',
#   'and',
#   'licens',
#   'that',
#   'might',
#   'give',
#   'your',
#   'applic',
#   'a',
#   'head',
#   'start'],
#  ['Well',
#   'spoken',
#   'english',
#   'is',
#   'necessari',
#   'for',
#   'thi',
#   'poistion',
#   'involv',
#   'take',
#   'order',
#   'from',
#   'customersW',
#   'need',
#   'someon',
#   'who',
#   'ha',
#   'work',
#   'in',
#   'a',
#   'cafe',
#   'befor',
#   'and',
#   'ha',
#   'a',
#   'bright',
#   'bubbl',
#   'person',
#   'to',
#   'greet',
#   'our',
#   'love',
#   'friendli',
#   'regular',
#   'and',
#   'build',
#   'good',
#   'relationship',
#   'with',
#   'themYour',
#   'roll',
#   'will',
#   'be',
#   'to',
#   'rememb',
#   'the',
#   'custom',
#   'and',
#   'their',
#   'usual',
#   'coffe',
#   'order',
#   'plu',
#   'help',
#   'out',
#   'other',
#   'area',
#   'in',
#   'the',
#   'cafe',
#   'as',
#   'requir'],
#  ['Specialist',
#   'Medic',
#   'Practition',
#   'Psychiatrist',
#   'Commun',
#   'Health',
#   'and',
#   'Human',
#   'Servic',
#   'and',
#   'Tasmanian',
#   'Health',
#   'Servic',
#   'Tasmanian',
#   'Health',
#   'Servic',
#   'North',
#   'West',
#   'Region',
#   'NorthWest',
#   'Applic',
#   'close',
#   'Saturday',
#   '20th',
#   'Februari',
#   '2016',
#   'Posit',
#   'detail',
#   'Posit',
#   'no',
#   '502790',
#   'Award',
#   'Salari',
#   'Medic',
#   'Practition',
#   'Interim',
#   'Agreement',
#   '2015',
#   'Classif',
#   'Specialist',
#   'Medic',
#   'Practition',
#   'Level',
#   '1',
#   'to',
#   'Senior',
#   'Specialist',
#   'Medic',
#   'Practition',
#   'Level',
#   '3',
#   'Salari',
#   '140592',
#   '213700',
#   'per',
#   'annum',
#   'Work',
#   'Type',
#   'FixedTerm',
#   'fulltim',
#   'day',
#   'worker',
#   'with',
#   'oncal',
#   'work',
#   '76',
#   'hour',
#   'per',
#   'fortnight',
#   'until',
#   '2019',
#   'Locat',
#   'Level',
#   '4',
#   'Parksid',
#   '1',
#   'Strahan',
#   'St',
#   'Pleas',
#   'note',
#   'that',
#   'access',
#   'to',
#   'the',
#   'Senior',
#   'Specialist',
#   'Medic',
#   'Practition',
#   'salari',
#   'rang',
#   '202',
#   '452',
#   '213',
#   '700',
#   'is',
#   'subject',
#   'to',
#   'the',
#   'success',
#   'applic',
#   'satisfi',
#   'the',
#   'criteria',
#   'for',
#   'Senior',
#   'Specialist',
#   'Medic',
#   'Practition',
#   'Level',
#   '1',
#   '2',
#   'or',
#   '3',
#   'as',
#   'describ',
#   'in',
#   'the',
#   'Salari',
#   'Medic',
#   'Practition',
#   'Interim',
#   'Agreement',
#   '2015',
#   'Who',
#   'are',
#   'we',
#   'The',
#   'Tasmanian',
#   'Health',
#   'Servic',
#   'is',
#   'an',
#   'innov',
#   'and',
#   'dynam',
#   'organis',
#   'dedic',
#   'to',
#   'improv',
#   'the',
#   'health',
#   'and',
#   'wellb',
#   'of',
#   'our',
#   'commun',
#   'We',
#   'are',
#   'commit',
#   'to',
#   'provid',
#   'the',
#   'highest',
#   'level',
#   'of',
#   'healthcar',
#   'and',
#   'servic',
#   'North',
#   'West',
#   'Tasmania',
#   'also',
#   'offer',
#   'a',
#   'brilliant',
#   'lifestyl',
#   'for',
#   'famili',
#   'with',
#   'afford',
#   'hous',
#   'excel',
#   'access',
#   'and',
#   'choic',
#   'of',
#   'educ',
#   'locat',
#   'within',
#   'strong',
#   'and',
#   'vibrant',
#   'rural',
#   'and',
#   'urban',
#   'centr',
#   'Our',
#   'pristin',
#   'wilder',
#   'and',
#   'coastlin',
#   'are',
#   'on',
#   'your',
#   'doorstep',
#   'and',
#   'your',
#   'work',
#   'life',
#   'balanc',
#   'will',
#   'ensur',
#   'that',
#   'you',
#   'have',
#   'the',
#   'best',
#   'of',
#   'both',
#   'world',
#   'We',
#   'offer',
#   'contemporari',
#   'well',
#   'equip',
#   'work',
#   'environ',
#   'excel',
#   'remuner',
#   'and',
#   'reloc',
#   'assist',
#   'Assist',
#   'with',
#   'AHPRA',
#   'registr',
#   'and',
#   'visa',
#   'sponsorship',
#   'is',
#   'avail',
#   'Who',
#   'are',
#   'we',
#   'look',
#   'for',
#   'An',
#   'opportun',
#   'ha',
#   'arisen',
#   'for',
#   'a',
#   'commun',
#   'psychiatrist',
#   'in',
#   'the',
#   'Adult',
#   'Commun',
#   'Mental',
#   'Health',
#   'Servic',
#   'in',
#   'NorthWest',
#   'Tasmania',
#   'The',
#   'Adult',
#   'Commun',
#   'Mental',
#   'Health',
#   'Servic',
#   'for',
#   'peopl',
#   'age',
#   '18',
#   'to',
#   '65',
#   'year',
#   'includ',
#   'a',
#   'mental',
#   'health',
#   'crisi',
#   'respons',
#   'through',
#   'Crisi',
#   'Assess',
#   'Triag',
#   'and',
#   'Treatment',
#   'CATT',
#   'servic',
#   'are',
#   'provid',
#   'from',
#   'base',
#   'at',
#   'Devonport',
#   'and',
#   'Burni',
#   'In',
#   'thi',
#   'role',
#   'the',
#   'psychiatrist',
#   'will',
#   'demonstr',
#   'their',
#   'extens',
#   'experi',
#   'and',
#   'skill',
#   'in',
#   'adult',
#   'gener',
#   'psychiatri',
#   'in',
#   'a',
#   'rang',
#   'of',
#   'practic',
#   'set',
#   'They',
#   'will',
#   'provid',
#   'comprehens',
#   'and',
#   'integr',
#   'gener',
#   'adult',
#   'psychiatr',
#   'servic',
#   'in',
#   'the',
#   'North',
#   'West',
#   'region',
#   'includ',
#   'Assess',
#   'and',
#   'treatment',
#   'of',
#   'adult',
#   'mental',
#   'health',
#   'client',
#   'at',
#   'variou',
#   'site',
#   'across',
#   'the',
#   'region',
#   'includ',
#   'inpati',
#   'set',
#   'commun',
#   'clinic',
#   'and',
#   'client',
#   'home',
#   'Particip',
#   'in',
#   'the',
#   'after',
#   'hour',
#   'on',
#   'call',
#   'roster',
#   'The',
#   'psychiatrist',
#   'will',
#   'also',
#   'promot',
#   'and',
#   'maintain',
#   'close',
#   'link',
#   'with',
#   'other',
#   'specialist',
#   'gener',
#   'practition',
#   'and',
#   'servic',
#   'provid',
#   'to',
#   'ensur',
#   'continu',
#   'of',
#   'patient',
#   'care',
#   'and',
#   'the',
#   'ongo',
#   'develop',
#   'of',
#   'the',
#   'mental',
#   'health',
#   'sector',
#   'What',
#   'can',
#   'we',
#   'offer',
#   'Negoti',
#   'salari',
#   'includ',
#   'superannu',
#   'and',
#   'access',
#   'to',
#   'salari',
#   'packag',
#   'Reloc',
#   'and',
#   'accommod',
#   'assist',
#   'Flexibl',
#   'work',
#   'life',
#   'balanc',
#   'Attract',
#   'Salari',
#   'Packag',
#   'Dynam',
#   'team',
#   'environ',
#   'Commit',
#   'to',
#   'ongo',
#   'profession',
#   'develop',
#   'In',
#   'order',
#   'to',
#   'be',
#   'consid',
#   'for',
#   'thi',
#   'posit',
#   'it',
#   'is',
#   'a',
#   'requir',
#   'that',
#   'you',
#   'address',
#   'the',
#   'select',
#   'criteria',
#   'which',
#   'are',
#   'locat',
#   'in',
#   'the',
#   'Statement',
#   'of',
#   'Duti',
#   'Desir',
#   'Requir',
#   'Current',
#   'Driver',
#   'Licenc',
#   'Essenti',
#   'Requir',
#   'Specialist',
#   'or',
#   'limit',
#   'registr',
#   'with',
#   'the',
#   'Medic',
#   'Board',
#   'of',
#   'Australia',
#   'in',
#   'a',
#   'relev',
#   'specialti',
#   'The',
#   'Head',
#   'of',
#   'the',
#   'State',
#   'Servic',
#   'ha',
#   'determin',
#   'that',
#   'the',
#   'person',
#   'nomin',
#   'for',
#   'thi',
#   'posit',
#   'is',
#   'to',
#   'satisfi',
#   'a',
#   'preemploy',
#   'check',
#   'befor',
#   'take',
#   'up',
#   'the',
#   'appoint',
#   'promot',
#   'transfer',
#   'The',
#   'follow',
#   'check',
#   'are',
#   'to',
#   'be',
#   'conduct',
#   '1',
#   'Convict',
#   'Check',
#   'in',
#   'the',
#   'follow',
#   'area',
#   'a',
#   'crime',
#   'of',
#   'violenc',
#   'b',
#   'sex',
#   'relat',
#   'offenc',
#   'cseriou',
#   'drug',
#   'offenc',
#   'and',
#   'd',
#   'crime',
#   'involv',
#   'dishonesti',
#   '2',
#   'Identif',
#   'Check',
#   '3',
#   'Disciplinari',
#   'action',
#   'in',
#   'previou',
#   'employ',
#   'check',
#   'You',
#   'are',
#   'encourag',
#   'to',
#   'appli',
#   'onlin',
#   'or',
#   'forward',
#   'your',
#   'hard',
#   'copi',
#   'applic',
#   'quot',
#   'the',
#   'vacanc',
#   'number',
#   'to',
#   'Human',
#   'Resourc',
#   'Tasmanian',
#   'Health',
#   'Servic',
#   'North',
#   'West',
#   'Region',
#   'PO',
#   'Box',
#   '258',
#   'Burni',
#   'Tasmania',
#   '7320',
#   'Pleas',
#   'note',
#   'if',
#   'you',
#   'are',
#   'appli',
#   'onlin',
#   'you',
#   'DO',
#   'NOT',
#   'need',
#   'to',
#   'upload',
#   'an',
#   'Applic',
#   'for',
#   'Employ',
#   'form',
#   'Better',
#   'health',
#   'and',
#   'qualiti',
#   'of',
#   'life',
#   'around',
#   'Tasmania',
#   'Visit',
#   'us',
#   'at',
#   'wwwthstasgovau'],
#  ['Princip',
#   'Advisor',
#   'Contract',
#   'Transport',
#   'and',
#   'Main',
#   'Road',
#   'Organis',
#   'site',
#   'Commerci',
#   'Transact',
#   'Passeng',
#   'Transport',
#   'Integr',
#   'TransLink',
#   'Brisban',
#   'In',
#   'the',
#   'role',
#   'of',
#   'Princip',
#   'Advisor',
#   'Contract',
#   'you',
#   'will',
#   'contribut',
#   'to',
#   'the',
#   'procur',
#   'of',
#   'a',
#   'portfolio',
#   'of',
#   'bu',
#   'contract',
#   'for',
#   'the',
#   'deliveri',
#   'of',
#   'public',
#   'transport',
#   'servic',
#   'in',
#   'South',
#   'East',
#   'Queensland',
#   'Thi',
#   'will',
#   'be',
#   'achiev',
#   'by',
#   'assist',
#   'the',
#   'evalu',
#   'and',
#   'negoti',
#   'of',
#   'new',
#   'contract',
#   'and',
#   'assess',
#   'the',
#   'perform',
#   'of',
#   'exist',
#   'contract',
#   'Job',
#   'detail',
#   'Job',
#   'type',
#   'Temporari',
#   'Fulltim',
#   'Occup',
#   'group',
#   'Project',
#   'Manag',
#   'Classif',
#   'AO7',
#   'Workplac',
#   'Locat',
#   'Brisban',
#   'Inner',
#   'Citi',
#   'Job',
#   'ad',
#   'refer',
#   'QLD',
#   '203030',
#   '16',
#   'Close',
#   'date',
#   '04Feb2016',
#   'Yearli',
#   'salari',
#   '100939',
#   '108231',
#   'Fortnightli',
#   'salari',
#   '386900',
#   '414850',
#   'Job',
#   'durat',
#   'For',
#   '12',
#   'month',
#   'with',
#   'possibl',
#   'extens',
#   'Contact',
#   'person',
#   'Boll',
#   'Borkowski',
#   'Contact',
#   'detail',
#   'Ph',
#   '07',
#   '3338',
#   '4070',
#   'Thi',
#   'role',
#   'involv',
#   'Manag',
#   'the',
#   'research',
#   'analysi',
#   'and',
#   'interpret',
#   'of',
#   'complex',
#   'contract',
#   'and',
#   'oper',
#   'issu',
#   'Assist',
#   'in',
#   'the',
#   'develop',
#   'of',
#   'new',
#   'contract',
#   'and',
#   'evalu',
#   'of',
#   'tender',
#   'submiss',
#   'Establish',
#   'process',
#   'tool',
#   'and',
#   'associ',
#   'contract',
#   'manag',
#   'system',
#   'for',
#   'a',
#   'team',
#   'of',
#   'contract',
#   'manag',
#   'respons',
#   'for',
#   'urban',
#   'bu',
#   'servic',
#   'contract',
#   'Transit',
#   'the',
#   'procur',
#   'project',
#   'to',
#   'busi',
#   'readi',
#   'through',
#   'a',
#   'busi',
#   'improv',
#   'initi',
#   'with',
#   'a',
#   'focu',
#   'on',
#   'process',
#   'effici',
#   'and',
#   'effect',
#   'intern',
#   'and',
#   'extern',
#   'stakehold',
#   'commun',
#   'The',
#   'ideal',
#   'candid',
#   'will',
#   'have',
#   'More',
#   'than',
#   '5',
#   'year',
#   'contract',
#   'manag',
#   'experi',
#   'in',
#   'a',
#   'high',
#   'valu',
#   'servic',
#   'contract',
#   'environ',
#   'Tertiari',
#   'qualif',
#   'in',
#   'Busi',
#   'Commerc',
#   'or',
#   'Procur',
#   'Experi',
#   'manag',
#   'transit',
#   'to',
#   'perform',
#   'base',
#   'contract',
#   'A',
#   'proven',
#   'record',
#   'in',
#   'improv',
#   'busi',
#   'process',
#   'and',
#   'effect',
#   'commun',
#   'of',
#   'such',
#   'Experi',
#   'in',
#   'scope',
#   'the',
#   'procur',
#   'of',
#   'variou',
#   'support',
#   'skill',
#   'Strong',
#   'comput',
#   'skill',
#   'and',
#   'interest',
#   'in',
#   'contract',
#   'manag',
#   'softwar',
#   'solut',
#   'Veri',
#   'strong',
#   'commun',
#   'problem',
#   'solv',
#   'negoti',
#   'mediat',
#   'and',
#   'present',
#   'skill',
#   'Strong',
#   'busi',
#   'acumen',
#   'person',
#   'drive',
#   'integr',
#   'and',
#   'resili',
#   'Thi',
#   'is',
#   'a',
#   'uniqu',
#   'and',
#   'rare',
#   'opportun',
#   'to',
#   'operationalis',
#   'new',
#   'bu',
#   'contract',
#   'with',
#   'the',
#   'object',
#   'of',
#   'streamlin',
#   'busi',
#   'process',
#   'improv',
#   'stakehold',
#   'relationship',
#   'and',
#   'tap',
#   'into',
#   'the',
#   'latest',
#   'technolog',
#   'to',
#   'ensur',
#   'both',
#   'parti',
#   'realis',
#   'contractu',
#   'benefit',
#   'Applic',
#   'to',
#   'remain',
#   'current',
#   'for',
#   'twelv',
#   'month',
#   'Further',
#   'inform',
#   'Two',
#   'temporari',
#   'fulltim',
#   'posit',
#   'avail',
#   'for',
#   'twelv',
#   'month',
#   'with',
#   'possibl',
#   'extens',
#   'Pleas',
#   'ensur',
#   'you',
#   'download',
#   'all',
#   'attach',
#   'and',
#   'follow',
#   'the',
#   'instruct',
#   'on',
#   'how',
#   'to',
#   'appli',
#   'Document',
#   'Befor',
#   'appli',
#   'for',
#   'thi',
#   'vacanc',
#   'pleas',
#   'ensur',
#   'you',
#   'read',
#   'the',
#   'document',
#   'below',
#   '203030',
#   '16',
#   'Role',
#   'Descript',
#   'Word',
#   '310KB',
#   'Off',
#   'line',
#   'Applic',
#   'form',
#   'PDF',
#   '739KB'],
#  ['Thi',
#   'posit',
#   'will',
#   'immedi',
#   'involv',
#   'the',
#   'Mechan',
#   'Project',
#   'Manag',
#   'in',
#   'guid',
#   'and',
#   'lead',
#   'a',
#   'team',
#   'on',
#   'current',
#   'develop',
#   'You',
#   'will',
#   'be',
#   'will',
#   'primarili',
#   'involv',
#   'in',
#   'the',
#   'deliveri',
#   'of',
#   'variou',
#   'HVAC',
#   'instal',
#   'and',
#   'it',
#   'coordin',
#   'along',
#   'with',
#   'the',
#   'other',
#   'disciplin',
#   'Regular',
#   'liaison',
#   'with',
#   'client',
#   'builder',
#   'and',
#   'site',
#   'base',
#   'staff',
#   'is',
#   'essenti',
#   'to',
#   'ensur',
#   'that',
#   'the',
#   'project',
#   'goe',
#   'as',
#   'program'],
#  ['We',
#   'are',
#   'seek',
#   'a',
#   'licens',
#   '20',
#   'tonn',
#   'excav',
#   'driver',
#   'with',
#   'experi',
#   'in',
#   'demolitionW',
#   'are',
#   'locat',
#   'in',
#   'the',
#   'eastern',
#   'suburb',
#   'of',
#   'Melbourn',
#   'most',
#   'of',
#   'our',
#   'work',
#   'is',
#   'in',
#   'the',
#   'Ringwood',
#   'area',
#   'You',
#   'must',
#   'have',
#   'your',
#   'own',
#   'transport',
#   'current',
#   'driver',
#   'licencelic',
#   'to',
#   'oper',
#   '20',
#   'tonn',
#   'excav',
#   'and',
#   'white',
#   'card',
#   'Thi',
#   'posit',
#   'is',
#   'casual',
#   'but',
#   'with',
#   'the',
#   'right',
#   'person',
#   'could',
#   'lead',
#   'to',
#   'full',
#   'time',
#   'employ',
#   'Pleas',
#   'contact',
#   'Kay',
#   'on7774',
#   'click',
#   'to',
#   'reveal',
#   'or',
#   'email',
#   'us',
#   'your',
#   'resum',
#   'interest',
#   'at',
#   'dgrau',
#   'click',
#   'to',
#   'reveal'],
#  ['Thi',
#   'role',
#   'exist',
#   'to',
#   'accumul',
#   'deep',
#   'busi',
#   'knowledg',
#   'confid',
#   'deliv',
#   'insight',
#   'advic',
#   'which',
#   'will',
#   'lead',
#   'to',
#   'action',
#   'measur',
#   'sustain',
#   'busi',
#   'opportun',
#   'within',
#   'the',
#   'sale',
#   'team',
#   'You',
#   'will',
#   'genuin',
#   'be',
#   'expect',
#   'to',
#   'have',
#   'a',
#   'voic',
#   'at',
#   'the',
#   'tabl',
#   'offer',
#   'guidanc',
#   'and',
#   'opinion',
#   'on',
#   'new',
#   'product',
#   'servic',
#   'and',
#   'best',
#   'practic'],
#  ['Work',
#   'and',
#   'holiday',
#   'at',
#   'same',
#   'time',
#   'sandwich',
#   'artist',
#   'requir',
#   'for',
#   'Subway',
#   'at',
#   'Rottnest',
#   'Island',
#   'need',
#   'urgent'],
#  ['nan'],
#  ['Do',
#   'you',
#   'need',
#   'a',
#   'hole',
#   'patch',
#   'in',
#   'your',
#   'plaster',
#   'wall',
#   'or',
#   'ceil',
#   'Give',
#   'jay',
#   'a',
#   'call',
#   'on',
#   '2335',
#   'click',
#   'to',
#   'reveal',
#   'for',
#   'a',
#   'free',
#   'quot',
#   'and',
#   'advic'],
#  ['Report',
#   'into',
#   'the',
#   'Project',
#   'Manag',
#   'you',
#   'will',
#   'be',
#   'respons',
#   'for',
#   'the',
#   'manag',
#   'of',
#   'the',
#   'trade',
#   'and',
#   'assist',
#   'with',
#   'lead',
#   'and',
#   'direct',
#   'all',
#   'site',
#   'activ',
#   'through',
#   'the',
#   'fit',
#   'out',
#   'process',
#   'an',
#   'initi',
#   'project',
#   'valu',
#   'at',
#   '18M',
#   'Further',
#   'respons',
#   'will',
#   'includ',
#   'manag',
#   'all',
#   'time',
#   'and',
#   'qualiti',
#   'aspect',
#   'on',
#   'the',
#   'project',
#   'to',
#   'ensur',
#   'all',
#   'work',
#   'are',
#   'complet',
#   'to',
#   'a',
#   'high',
#   'standard'],
#  ['nan'],
#  ['All',
#   'Trade',
#   'Queensland',
#   'are',
#   'seek',
#   'a',
#   'reliabl',
#   'and',
#   'hardwork',
#   '1st',
#   'Year',
#   'Apprentic',
#   'Boat',
#   'Builder',
#   'to',
#   'start',
#   'out',
#   'their',
#   'apprenticeship',
#   'with',
#   'one',
#   'of',
#   'our',
#   'client',
#   'base',
#   'at',
#   'Coomera',
#   'on',
#   'the',
#   'Gold',
#   'Coast'],
#  ['We',
#   'are',
#   'look',
#   'for',
#   'Car',
#   'washer',
#   'who',
#   'can',
#   'also',
#   'serv',
#   'custom',
#   'Work',
#   'hour',
#   'will',
#   'be',
#   '11',
#   'pm',
#   'to',
#   '7am',
#   'As',
#   'our',
#   'custom',
#   'base',
#   'is',
#   'mostli',
#   'asian',
#   'Asian',
#   'Indian',
#   'applic',
#   'will',
#   'be',
#   'preffer'],
#  ['nan'],
#  ['Our',
#   'client',
#   'is',
#   'a',
#   'larg',
#   'and',
#   'trust',
#   'furnitur',
#   'remov',
#   'compani',
#   'Applic',
#   'have',
#   'now',
#   'open',
#   'for',
#   'a',
#   'client',
#   'face',
#   'driver',
#   'labour',
#   'role',
#   'the',
#   'success',
#   'candid',
#   'will',
#   'work',
#   'for',
#   'the',
#   'Self',
#   'Storag',
#   'Divis',
#   'in',
#   'both',
#   'warehous',
#   'oper',
#   'and',
#   'deliveri',
#   'pick',
#   'up',
#   'You',
#   'would',
#   'need',
#   'to',
#   'be',
#   'physic',
#   'fit',
#   'have',
#   'excel',
#   'commun',
#   'skill',
#   'and',
#   'be',
#   'comfort',
#   'deal',
#   'with',
#   'member',
#   'of',
#   'the',
#   'public',
#   'and',
#   'corpor',
#   'client'],
#  ['Busi',
#   'wine',
#   'bar',
#   'restaur',
#   'in',
#   'the',
#   'Sutherland',
#   'Shire',
#   'area',
#   'requir',
#   'experienc',
#   'waitstaff',
#   'to',
#   'join',
#   'their',
#   'team',
#   'for',
#   'an',
#   'immedi',
#   'start',
#   'You',
#   'will',
#   'need',
#   'to',
#   'be',
#   'abl',
#   'to',
#   'work',
#   'independ',
#   'and',
#   'be',
#   'respons',
#   'for',
#   'your',
#   'task',
#   'that',
#   'are',
#   'assign',
#   'to',
#   'you',
#   'You',
#   'must',
#   'also',
#   'be',
#   'organis',
#   'and',
#   'be',
#   'an',
#   'all',
#   'rounder',
#   'and',
#   'work',
#   'well',
#   'within',
#   'a',
#   'team',
#   'environ',
#   'Applic',
#   'with',
#   'experi',
#   'in',
#   'use',
#   'espresso',
#   'machin',
#   'and',
#   'or',
#   'have',
#   'bar',
#   'experi',
#   'a',
#   'definit',
#   'advantag',
#   'Applic',
#   'must',
#   'also',
#   'show',
#   'drive',
#   'and',
#   'great',
#   'custom',
#   'servic',
#   'at',
#   'all',
#   'time',
#   'Pleas',
#   'email',
#   'all',
#   'resum',
#   'to',
#   'deaau',
#   'click',
#   'to',
#   'reveal'],
#  ['Where',
#   'you',
#   'are',
#   'reward',
#   'for',
#   'your',
#   'hard',
#   'work',
#   'work',
#   'weekend',
#   'is',
#   'option',
#   'where',
#   'stun',
#   'beach',
#   'rug',
#   'mountain',
#   'roll',
#   'vineyard',
#   'are',
#   'on',
#   'your',
#   'doorstep',
#   'where',
#   'the',
#   'winter',
#   'are',
#   'mild',
#   'the',
#   'summer',
#   'are',
#   'summer'],
#  ['Courier',
#   'Premier',
#   'and',
#   'Cabinet',
#   'Corpor',
#   'Govern',
#   'Properti',
#   'and',
#   'Procur',
#   'North',
#   'Applic',
#   'close',
#   'Friday',
#   '15th',
#   'Januari',
#   '2016',
#   'Posit',
#   'detail',
#   'Posit',
#   'no',
#   '470487',
#   'Award',
#   'Tasmanian',
#   'State',
#   'Servic',
#   'Award',
#   'Classif',
#   'Gener',
#   'Stream',
#   'Band',
#   '1',
#   'Salari',
#   '40511',
#   '49969',
#   'per',
#   'annum',
#   'Work',
#   'Type',
#   'Perman',
#   'fulltim',
#   'Locat',
#   'Launceston',
#   'Duti',
#   'The',
#   'Courier',
#   'Driver',
#   'is',
#   'part',
#   'of',
#   'a',
#   'team',
#   'which',
#   'provid',
#   'effici',
#   'and',
#   'effect',
#   'courier',
#   'servic',
#   'in',
#   'the',
#   'deliveri',
#   'collect',
#   'and',
#   'accur',
#   'sort',
#   'of',
#   'govern',
#   'mail',
#   'The',
#   'Courier',
#   'Driver',
#   'also',
#   'undertak',
#   'the',
#   'basic',
#   'mainten',
#   'and',
#   'cleanli',
#   'of',
#   'the',
#   'vehicl',
#   'and',
#   'coordin',
#   'schedul',
#   'servic',
#   'Essenti',
#   'Requir',
#   'Current',
#   'Driver',
#   'Licenc'],
#  ['nan'],
#  ['To',
#   'be',
#   'success',
#   'in',
#   'thi',
#   'role',
#   'you',
#   'will',
#   'have',
#   'at',
#   'least',
#   '2',
#   'year',
#   'experi',
#   'work',
#   'as',
#   'a',
#   'travel',
#   'consult',
#   'Addit',
#   'experi',
#   'use',
#   'Galileo',
#   'CR',
#   'would',
#   'be',
#   'benefici',
#   'for',
#   'thi',
#   'posit'],
#  ['Mk2',
#   'are',
#   'seek',
#   'a',
#   'talent',
#   'Civil',
#   'Supervisor',
#   'that',
#   'ha',
#   'excel',
#   'commun',
#   'and',
#   'leadership',
#   'skill',
#   'and',
#   'can',
#   'work',
#   'autonom',
#   'onsit',
#   'with',
#   'a',
#   'crew',
#   'of',
#   'up',
#   'to',
#   '10',
#   'employe'],
#  ['nan'],
#  ['nan'],
#  ['Look',
#   'for',
#   'a',
#   'keen',
#   'hardwork',
#   'labour',
#   'trowel',
#   'to',
#   'join',
#   'our',
#   'team',
#   'Pebblecret',
#   'swim',
#   'pool',
#   'in',
#   'area',
#   'rang',
#   'from',
#   'Sydney',
#   'to',
#   'Newcastl',
#   'Must',
#   'be',
#   'will',
#   'to',
#   'travel',
#   'MUST',
#   'HAVE',
#   'SUFFICI',
#   'AMOUNT',
#   'OF',
#   'PEBBLECRET',
#   'EXPERI',
#   'Email',
#   'detail',
#   'to',
#   'peaau',
#   'click',
#   'to',
#   'reveal'],
#  ['ShoreContract',
#   'is',
#   'look',
#   'for',
#   'a',
#   'respons',
#   'wellspoken',
#   'junior',
#   'to',
#   'becom',
#   'part',
#   'ofour',
#   'team',
#   'The',
#   'success',
#   'applic',
#   'will',
#   'be',
#   'place',
#   'in',
#   'a',
#   'team',
#   'with',
#   'matur',
#   'skill',
#   'tradesmen',
#   'to',
#   'learn',
#   'all',
#   'the',
#   'necessari',
#   'skill',
#   'need',
#   'in',
#   'the',
#   'civilconstruct',
#   'industri',
#   'Thi',
#   'will',
#   'be',
#   'a',
#   'full',
#   'time',
#   'traine',
#   'posit',
#   'onc',
#   'a',
#   'trialperiod',
#   'ha',
#   'been',
#   'serv'],
#  ['nan'],
#  ['Our',
#   'client',
#   'is',
#   'seek',
#   'an',
#   'experienc',
#   'Storeman',
#   'to',
#   'work',
#   'at',
#   'a',
#   'High',
#   'End',
#   'furnitur',
#   'import',
#   'in',
#   'Springval',
#   'Report',
#   'to',
#   'the',
#   'Warehous',
#   'manag',
#   'your',
#   'duti',
#   'will',
#   'be',
#   'vari',
#   'and',
#   'includ'],
#  ['I',
#   'am',
#   'seek',
#   'an',
#   'experienc',
#   'travel',
#   'consult',
#   'who',
#   'is',
#   'well',
#   'vers',
#   'in',
#   'the',
#   'Amadeu',
#   'GD',
#   'system',
#   'I',
#   'work',
#   'in',
#   'travel',
#   'and',
#   'use',
#   'the',
#   'system',
#   'occasion',
#   'and',
#   'would',
#   'like',
#   'to',
#   'pick',
#   'up',
#   'some',
#   'basicintermedi',
#   'knowledg',
#   'over',
#   'the',
#   'cours',
#   'of',
#   '34',
#   'train',
#   'session',
#   'If',
#   'you',
#   'are',
#   'local',
#   'to',
#   'the',
#   'Sydney',
#   'area',
#   'I',
#   'will',
#   'pay',
#   '40',
#   'per',
#   'hour',
#   'for',
#   'one',
#   'on',
#   'one',
#   'train',
#   'roughli',
#   '2',
#   'night',
#   'a',
#   'week',
#   'if',
#   'you',
#   'are',
#   'base',
#   'region',
#   'I',
#   'will',
#   'pay',
#   '30',
#   'per',
#   'hour',
#   'I',
#   'am',
#   'fairli',
#   'flexibl',
#   'as',
#   'to',
#   'time',
#   'as',
#   'long',
#   'as',
#   'it',
#   'is',
#   'in',
#   'the',
#   'even',
#   'If',
#   'remot',
#   'you',
#   'will',
#   'need',
#   'to',
#   'have',
#   'access',
#   'to',
#   'team',
#   'viewer',
#   'or',
#   'go',
#   'to',
#   'meet',
#   'ani',
#   'screen',
#   'share',
#   'platform',
#   'and',
#   'can',
#   'talk',
#   'me',
#   'through',
#   'the',
#   'Amadeu',
#   'instal',
#   'on',
#   'YOUR',
#   'comput',
#   'If',
#   'your',
#   'are',
#   'interest',
#   'pleas',
#   'give',
#   'me',
#   'a',
#   'call',
#   'and',
#   'we',
#   'can',
#   'discuss',
#   'in',
#   'more',
#   'detail',
#   'Mani',
#   'Thank',
#   'Nick'],
#  ['Success',
#   'applic',
#   'will',
#   'work',
#   'in',
#   'a',
#   'small',
#   'but',
#   'veri',
#   'passion',
#   'kitchen',
#   'team',
#   'with',
#   'great',
#   'food',
#   'We',
#   'look',
#   'forward',
#   'to',
#   'hear',
#   'from',
#   'you',
#   'The',
#   'Hawk',
#   'Hunter',
#   'Team'],
#  ['We',
#   'are',
#   'look',
#   'for',
#   'a',
#   'fulltim',
#   'or',
#   'parttim',
#   'waiter',
#   'for',
#   'our',
#   'shop',
#   'we',
#   'are',
#   'seek',
#   'for',
#   'someon',
#   'reliabl',
#   'with',
#   'good',
#   'commun',
#   'skill',
#   'hard',
#   'work',
#   'a',
#   'fast',
#   'worker',
#   'Our',
#   'shop',
#   'ha',
#   'a',
#   'rang',
#   'of',
#   'sushi',
#   'to',
#   'hot',
#   'food',
#   'and',
#   'soup',
#   'and',
#   'noodl',
#   'eg',
#   'Stir',
#   'fri',
#   'Sushi',
#   'fri',
#   'rice',
#   'laksa',
#   'soup',
#   'and',
#   'mani',
#   'more',
#   'The',
#   'posit',
#   'includ',
#   'set',
#   'up',
#   'shop',
#   'clean',
#   'custom',
#   'servic',
#   'some',
#   'dish',
#   'wash',
#   'etc',
#   'The',
#   'right',
#   'candid',
#   'must',
#   'be',
#   'will',
#   'to',
#   'learn',
#   'keen',
#   'worker',
#   'reliabl',
#   'abl',
#   'to',
#   'work',
#   'in',
#   'fast',
#   'past',
#   'Train',
#   'is',
#   'provid',
#   'experi',
#   'is',
#   'not',
#   'essenti',
#   'but',
#   'will',
#   'help',
#   'Pleas',
#   'do',
#   'not',
#   'appli',
#   'after',
#   'check',
#   'the',
#   'locat',
#   '12',
#   'Jackson',
#   'road',
#   'warriewood',
#   '2102',
#   'Pleas',
#   'email',
#   'me',
#   'resum',
#   'to',
#   'edscom',
#   'click',
#   'to',
#   'reveal'],
#  ['We',
#   'are',
#   'look',
#   'for',
#   'an',
#   'enthusiast',
#   'care',
#   'physiotherapist',
#   'who',
#   'is',
#   'will',
#   'to',
#   'join',
#   'our',
#   'progress',
#   'and',
#   'grow',
#   'practic',
#   'in',
#   'Hurstvil',
#   'NSW',
#   'As',
#   'the',
#   'area',
#   'ha',
#   'becom',
#   'more',
#   'popular',
#   'for',
#   'Chines',
#   'commun',
#   'thu',
#   'physiotherapist',
#   'with',
#   'multipl',
#   'languag',
#   'abil',
#   'is',
#   'prefer',
#   'New',
#   'graduat',
#   'are',
#   'welcom',
#   'Our',
#   'clinic',
#   'ha',
#   'establish',
#   'for',
#   'more',
#   'than',
#   '5',
#   'year',
#   'at',
#   'a',
#   'busi',
#   'locat',
#   'just',
#   '1',
#   'min',
#   'walk',
#   'from',
#   'the',
#   'train',
#   'station',
#   'therefor',
#   'veri',
#   'strong',
#   'potenti',
#   'for',
#   'your',
#   'career',
#   'growth',
#   'It',
#   'a',
#   'friendli',
#   'and',
#   'support',
#   'work',
#   'environ',
#   'that',
#   'we',
#   'offer',
#   'competit',
#   'remuner',
#   'rate',
#   'and',
#   'great',
#   'flexibl',
#   'in',
#   'the',
#   'posit',
#   'We',
#   'are',
#   'look',
#   'for',
#   'applic',
#   'with'],
#  ['You',
#   'will',
#   'be',
#   'respons',
#   'for',
#   'updat',
#   'data',
#   'in',
#   'SAP',
#   'Plant',
#   'Mainten',
#   'EAM',
#   'and',
#   'for',
#   'reduc',
#   'the',
#   'backlog',
#   'of',
#   'data',
#   'collect',
#   'entri',
#   'and',
#   'manag',
#   'Thi',
#   'will',
#   'includ',
#   'check',
#   'exist',
#   'equip',
#   'and',
#   'function',
#   'locat',
#   'inform',
#   'and',
#   'characterist',
#   'You',
#   'will',
#   'also',
#   'be',
#   'assist',
#   'variou',
#   'engin',
#   'project',
#   'with',
#   'a',
#   'focu',
#   'on',
#   'contract',
#   'and',
#   'gener',
#   'administr',
#   'work'],
#  ['Locat',
#   'on',
#   'the',
#   'outskirt',
#   'of',
#   'the',
#   'Sydney',
#   'CBD',
#   'Set',
#   'in',
#   'a',
#   'modern',
#   'fashion',
#   'upscal',
#   'venu',
#   'Where',
#   'the',
#   'custom',
#   '1st',
#   'hand',
#   'trust',
#   'and',
#   'experi',
#   'the',
#   'skill',
#   'and',
#   'finess',
#   'of',
#   'the',
#   'chef',
#   'basic',
#   'to',
#   'be',
#   'blown',
#   'away',
#   'As',
#   'they',
#   'usual',
#   'choos',
#   'and',
#   'come',
#   'up',
#   'with',
#   'the',
#   'menu',
#   'for',
#   'major',
#   'of',
#   'the',
#   'custom',
#   'With',
#   'the',
#   'menu',
#   'it',
#   'more',
#   'seafood',
#   'focus',
#   'then',
#   'anyth',
#   'els'],
#  ['We',
#   'have',
#   'recent',
#   'taken',
#   'over',
#   'a',
#   'well',
#   'known',
#   'cafe',
#   'in',
#   'North',
#   'Sydney',
#   'and',
#   'are',
#   'look',
#   'for',
#   'an',
#   'experienc',
#   'Barista',
#   'to',
#   'help',
#   'us',
#   'significantli',
#   'rais',
#   'the',
#   'standard',
#   'of',
#   'the',
#   'coffe',
#   'offer'],
#  ['Larg',
#   'and',
#   'reput',
#   'Perth',
#   'compani',
#   'look',
#   'for',
#   'a',
#   'crane',
#   'driver',
#   'for',
#   'a',
#   'week',
#   'from',
#   'the',
#   '7th',
#   'to',
#   '13th',
#   'of',
#   'Januari',
#   'Neerabup',
#   'work',
#   'site',
#   'Oper',
#   '60t',
#   'crane',
#   'Assist',
#   'ground',
#   'crew',
#   'as',
#   'requir'],
#  ['nan'],
#  ['nan'],
#  ['We',
#   'are',
#   'current',
#   'on',
#   'the',
#   'lookout',
#   'for',
#   'enthusiast',
#   'and',
#   'motiv',
#   'Casual',
#   'Sale',
#   'Assist',
#   'to',
#   'work',
#   'in',
#   'Womenswear',
#   'Menswear',
#   'depart',
#   'our',
#   'new',
#   'and',
#   'excit',
#   'concess',
#   'store',
#   'in',
#   'Myer',
#   'Southland',
#   'open',
#   'in',
#   'earli',
#   '2016',
#   'Previou',
#   'experi',
#   'work',
#   'in',
#   'fashion',
#   'retail',
#   'or',
#   'in',
#   'a',
#   'similar',
#   'depart',
#   'store',
#   'will',
#   'be',
#   'highli',
#   'advantag'],
#  ['Intro',
#   'Recruit',
#   'Solut',
#   'ha',
#   'an',
#   'opportun',
#   'for',
#   '4',
#   'plaster',
#   'to',
#   'join',
#   'one',
#   'of',
#   'Brisban',
#   'top',
#   'plaster',
#   'contractor',
#   'Thi',
#   'contractor',
#   'ha',
#   'major',
#   'contract',
#   'with',
#   'Brisban',
#   'premier',
#   'fit',
#   'out',
#   'compani'],
#  ['Consult',
#   'Industri',
#   'Relat',
#   'Premier',
#   'and',
#   'Cabinet',
#   'State',
#   'Servic',
#   'Manag',
#   'Offic',
#   'South',
#   'Applic',
#   'close',
#   'Friday',
#   '15th',
#   'Januari',
#   '2016',
#   'Posit',
#   'detail',
#   'Posit',
#   'no',
#   '002287',
#   'Award',
#   'Tasmanian',
#   'State',
#   'Servic',
#   'Award',
#   'Classif',
#   'Gener',
#   'Stream',
#   'Band',
#   '6',
#   'Salari',
#   '86230',
#   '97646',
#   'per',
#   'annum',
#   'Work',
#   'Type',
#   'Perman',
#   'fulltim',
#   'Locat',
#   'Hobart',
#   'Duti',
#   'Provid',
#   'specialis',
#   'advic',
#   'and',
#   'interpret',
#   'of',
#   'industri',
#   'relat',
#   'instrument',
#   'includ',
#   'polici',
#   'legisl',
#   'regul',
#   'and',
#   'guidelin',
#   'that',
#   'defin',
#   'the',
#   'oper',
#   'framework',
#   'for',
#   'the',
#   'state',
#   'servic',
#   'and',
#   'agenc',
#   'and',
#   'provid',
#   'option',
#   'and',
#   'solut',
#   'for',
#   'improv',
#   'employ',
#   'manag',
#   'Repres',
#   'the',
#   'state',
#   'servic',
#   'and',
#   'agenc',
#   'in',
#   'a',
#   'varieti',
#   'of',
#   'set',
#   'rang',
#   'from',
#   'formal',
#   'hear',
#   'to',
#   'inform',
#   'discuss',
#   'includ',
#   'negoti',
#   'across',
#   'a',
#   'rang',
#   'of',
#   'complex',
#   'sensit',
#   'industri',
#   'relat',
#   'matter',
#   'Desir',
#   'Requir',
#   'Appropri',
#   'tertiari',
#   'qualif',
#   'and',
#   'or',
#   'extens',
#   'experi',
#   'in',
#   'employ',
#   'manag',
#   'incorpor',
#   'advocaci',
#   'polici',
#   'develop',
#   'and',
#   'a',
#   'comprehens',
#   'knowledg',
#   'of',
#   'employ',
#   'polici',
#   'practic',
#   'and',
#   'regul'],
#  ['Mangrov',
#   'HotelBroom',
#   'is',
#   'look',
#   'for',
#   'a',
#   'SousChef',
#   'Chef',
#   'de',
#   'Parti',
#   'to',
#   'join',
#   'our',
#   'team',
#   'Applic',
#   'must',
#   'have',
#   '·',
#   'Abil',
#   'to',
#   'work',
#   'full',
#   'time',
#   'on',
#   'a',
#   'rotat',
#   'roster',
#   '·',
#   'Relev',
#   'Australian',
#   'work',
#   'visa'],
#  ['Crab',
#   'claw',
#   'island',
#   'resort',
#   'is',
#   'look',
#   'for',
#   'a',
#   'chef',
#   'cook',
#   'kitchen',
#   'hand',
#   'short',
#   'order',
#   'cook',
#   'for',
#   'approx',
#   'two',
#   'month',
#   'workposs',
#   'of',
#   'full',
#   'time',
#   'approx',
#   '40',
#   '45',
#   'hour',
#   'per',
#   'week',
#   'Live',
#   'in',
#   'posit',
#   'with',
#   'meal',
#   'and',
#   'accommod',
#   'provid',
#   'coupl',
#   'consid',
#   'Immedi',
#   'start',
#   'prefer',
#   'Great',
#   'locat',
#   'great',
#   'team'],
#  ['nan'],
#  ['As',
#   'a',
#   'Freight',
#   'handler',
#   'you',
#   'will',
#   'requir',
#   'excel',
#   'plan',
#   'and',
#   'organ',
#   'skill',
#   'with',
#   'posit',
#   'custom',
#   'servic',
#   'presenc',
#   'in',
#   'the',
#   'depot',
#   'Thi',
#   'posit',
#   'requir',
#   'you',
#   'to',
#   'work',
#   'in',
#   'a',
#   'regul',
#   'workplac',
#   'that',
#   'pride',
#   'itself',
#   'on',
#   'meet',
#   'strict',
#   'deadlin',
#   'in',
#   'a',
#   'schedul',
#   'driven',
#   'environ',
#   'Part',
#   'of',
#   'the',
#   'key',
#   'to',
#   'your',
#   'success',
#   'is',
#   'your',
#   'experi',
#   'in',
#   'build',
#   'relationship',
#   'with',
#   'colleagu'],
#  ['To',
#   'support',
#   'their',
#   'continu',
#   'growth',
#   'we',
#   'are',
#   'current',
#   'recruit',
#   'for',
#   'a',
#   'Dismantl',
#   'to',
#   'join',
#   'the',
#   'team',
#   'at',
#   'the',
#   'Smithfield',
#   'site',
#   'The',
#   'role',
#   'will',
#   'report',
#   'to',
#   'the',
#   'Product',
#   'Manag',
#   'and',
#   'be',
#   'respons',
#   'for',
#   'the',
#   'dismantl',
#   'of',
#   'our',
#   'incom',
#   'vehicl',
#   'for',
#   'storag',
#   'at',
#   'our',
#   'state',
#   'of',
#   'the',
#   'art',
#   'wareh',
#   'facil',
#   'and',
#   'for',
#   'sale',
#   'to',
#   'the',
#   'collis',
#   'repair',
#   'and',
#   'mechan',
#   'repair',
#   'industri'],
#  ['An',
#   'opportun',
#   'ha',
#   'becom',
#   'avail',
#   'for',
#   'an',
#   'enthusiast',
#   'and',
#   'commit',
#   'care',
#   'manag',
#   'who',
#   'is',
#   'look',
#   'to',
#   'join',
#   'one',
#   'of',
#   'the',
#   'largest',
#   'provid',
#   'of',
#   'age',
#   'care',
#   'facil',
#   'in',
#   'ACT'],
#  ['nan'],
#  ['You',
#   'will',
#   'join',
#   'a',
#   'collabor',
#   'team',
#   'of',
#   'GP',
#   'Obstetrician',
#   'and',
#   'Gynaecologist',
#   'as',
#   'well',
#   'as',
#   '4',
#   'advanc',
#   'DRANZOG',
#   'in',
#   'a',
#   'role',
#   'that',
#   'will',
#   'requir',
#   'the',
#   'success',
#   'candid',
#   'to',
#   'lead',
#   'and',
#   'deliv',
#   'an',
#   'excel',
#   'standard',
#   'of',
#   'clinic',
#   'care',
#   'to',
#   'a',
#   'commun',
#   'of',
#   'approxim',
#   '30000',
#   'peopl',
#   'The',
#   'servic',
#   'manag',
#   'approxim',
#   '800',
#   'birth',
#   'per',
#   'annum',
#   'You',
#   'will',
#   'be',
#   'respons',
#   'for',
#   'provid',
#   'administr',
#   'leadership',
#   'alongsid',
#   'the',
#   'Clinic',
#   'Nurs',
#   'Specialist',
#   'of',
#   'Matern'],
#  ['Take',
#   'advantag',
#   'of',
#   'Sydney',
#   'construct',
#   'boom',
#   'A',
#   'great',
#   'opportun',
#   'exist',
#   'for',
#   'experienc',
#   'carpet',
#   'layer',
#   'will',
#   'to',
#   'work',
#   'in',
#   'a',
#   'demand',
#   'busi',
#   'environ',
#   'Residenti',
#   'commerci',
#   'work',
#   'with',
#   'unlimit',
#   'potenti',
#   'Ongo',
#   'work',
#   'for',
#   'instal',
#   'with',
#   'good',
#   'work',
#   'ethic',
#   'qualiti',
#   'workmanship',
#   'person',
#   'charact',
#   'abil',
#   'to',
#   'commun',
#   'with',
#   'client',
#   'manag',
#   'etc',
#   'Can',
#   'you',
#   'provid',
#   'work',
#   'refer',
#   'with',
#   'proven',
#   'experi',
#   'as',
#   'a',
#   'carpet',
#   'layer'],
#  ['nan'],
#  ['nan'],
#  ['There',
#   'are',
#   'fantast',
#   'opportun',
#   'for',
#   'Gener',
#   'Practition',
#   'to',
#   'work',
#   'within',
#   'clinic',
#   'scatter',
#   'around',
#   'the',
#   'Brisban',
#   'and',
#   'Gold',
#   'Coast',
#   'Due',
#   'to',
#   'Patient',
#   'demand',
#   'mani',
#   'of',
#   'the',
#   'clinic',
#   'are',
#   'open',
#   'through',
#   'to',
#   '1100pm',
#   'with',
#   'weekend',
#   'appoint',
#   'avail',
#   'You',
#   'will',
#   'have',
#   'the',
#   'chanc',
#   'to',
#   'negoti',
#   'hour',
#   'that',
#   'are',
#   'flexibl',
#   'with',
#   'your',
#   'lifestyl',
#   'whether',
#   'that',
#   'be',
#   'Full',
#   'Time',
#   'Part',
#   'time',
#   'or',
#   'After',
#   'Hour',
#   'You',
#   'will',
#   'be',
#   'base',
#   'in',
#   'one',
#   'clinic',
#   'howev',
#   'could',
#   'transfer',
#   'to',
#   'one',
#   'of',
#   'the',
#   'other',
#   '10',
#   'if',
#   'you',
#   'would',
#   'like',
#   'more',
#   'hour',
#   'or',
#   'a',
#   'chang'],
#  ['The',
#   'Lorn',
#   'Beach',
#   'Pavilion',
#   'in',
#   'Lorn',
#   'is',
#   'hire',
#   'chef',
#   'cook',
#   'casual',
#   'immedi',
#   'We',
#   'are',
#   'one',
#   'of',
#   'the',
#   'biggest',
#   'venu',
#   'in',
#   'town',
#   'serv',
#   'breakfast',
#   'lunch',
#   'and',
#   'dinner',
#   '7',
#   'day',
#   'a',
#   'week',
#   'as',
#   'well',
#   'as',
#   'host',
#   'up',
#   'to',
#   '34',
#   'wed',
#   'a',
#   'week',
#   'over',
#   'summer',
#   'If',
#   'you',
#   'like',
#   'a',
#   'challeng',
#   'want',
#   'to',
#   'be',
#   'part',
#   'of',
#   'a',
#   'young',
#   'and',
#   'energet',
#   'hospit',
#   'group',
#   'and',
#   'can',
#   'imagin',
#   'move',
#   'to',
#   'Lorn',
#   'Great',
#   'Ocean',
#   'Road',
#   'get',
#   'in',
#   'touch',
#   'with',
#   'us',
#   'for',
#   'more',
#   'detail'],
#  ['If',
#   'you',
#   'are',
#   'an',
#   'experienc',
#   'Barista',
#   'with',
#   'a',
#   'minimum',
#   'of',
#   '2',
#   'year',
#   'experi',
#   'thi',
#   'is',
#   'the',
#   'job',
#   'for',
#   'you',
#   'Must',
#   'be',
#   'abl',
#   'to',
#   'work',
#   'even',
#   'and',
#   'weekend',
#   'part',
#   'time',
#   'and',
#   'full',
#   'time',
#   'posit',
#   'avail',
#   'Pleas',
#   'email',
#   'through',
#   'you',
#   'resum',
#   'to',
#   'the',
#   'email',
#   'provid'],
#  ['Purpos',
#   'of',
#   'the',
#   'role',
#   'is',
#   'to',
#   'drive',
#   'visibl',
#   'impact',
#   'of',
#   'Enterpris',
#   'Market',
#   'Invest',
#   'across',
#   'commerci',
#   'and',
#   'public',
#   'sector',
#   'in',
#   'the',
#   'enterpris',
#   'Thi',
#   'role',
#   'work',
#   'close',
#   'with',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'enterpris',
#   'market',
#   'team',
#   'to',
#   'ensur',
#   'enterpris',
#   'market',
#   'busi',
#   'outcom',
#   'are',
#   'met',
#   'through',
#   'the',
#   'execut',
#   'the',
#   'audienc',
#   'engag',
#   'plan',
#   'target',
#   'busi',
#   'and',
#   'technolog',
#   'leadership',
#   'audienc',
#   'within',
#   'Microsoft',
#   'top',
#   '1500',
#   'client',
#   'in',
#   'Australia',
#   'Measur',
#   'of',
#   'thi',
#   'impact',
#   'is',
#   'in',
#   'the',
#   'form',
#   'of',
#   'new',
#   'lead',
#   'opportun',
#   'qualifi',
#   'as',
#   'well',
#   'as',
#   'acceler',
#   'and',
#   'close',
#   'busi'],
#  ['We',
#   'are',
#   'seek',
#   'a',
#   'Floor',
#   'Sale',
#   'Consult',
#   'for',
#   'our',
#   'Rockhampton',
#   'store',
#   'Floor',
#   'Sale',
#   'Consult',
#   'provid',
#   'specialist',
#   'product',
#   'advic',
#   'to',
#   'custom',
#   'and',
#   'ensur',
#   'a',
#   'high',
#   'standard',
#   'of',
#   'custom',
#   'servic',
#   'and',
#   'present',
#   'of',
#   'product',
#   'in',
#   'the',
#   'store'],
#  ['Experienc',
#   'chef',
#   'need',
#   'for',
#   'parttim',
#   'hour',
#   '1530',
#   'at',
#   'fine',
#   'dine',
#   'restaur',
#   'in',
#   'Airli',
#   'Beach',
#   'Weekend',
#   'Lunch',
#   'shift',
#   'and',
#   'some',
#   'dinner',
#   'shift',
#   'avail'],
#  ['If',
#   'you',
#   'have',
#   'other',
#   'mine',
#   'site',
#   'induct',
#   'in',
#   'Qld',
#   'we',
#   'are',
#   'happi',
#   'to',
#   'consid',
#   'you',
#   'for',
#   'other',
#   'shutdown',
#   'we',
#   'have',
#   'come',
#   'up',
#   'Pleas',
#   'email',
#   'your',
#   'resum',
#   'below',
#   'to',
#   'be',
#   'consid',
#   'for',
#   'these',
#   'positio'],
#  ['Unleash',
#   'your',
#   'Potenti',
#   'with',
#   'Chandler',
#   'Macleod',
#   'by',
#   'becom',
#   'a',
#   'School',
#   'Cross',
#   'Supervisor',
#   'Work',
#   'within',
#   'the',
#   'Local',
#   'Govern',
#   'Industri',
#   'assist',
#   'and',
#   'educ',
#   'our',
#   'young',
#   'gener',
#   'about',
#   'road',
#   'safeti'],
#  ['We',
#   'are',
#   'in',
#   'need',
#   'of',
#   'ajunior',
#   'barista',
#   'cafe',
#   'allround',
#   'Duti',
#   'includ',
#   'assist',
#   'the',
#   'baristamak',
#   'coffe',
#   'and',
#   'other',
#   'hot',
#   'drink',
#   'take',
#   'order',
#   'food',
#   'prep',
#   'as',
#   'well',
#   'as',
#   'otherduti'],
#  ['Tuggerah',
#   'Sport',
#   'and',
#   'Spinal',
#   'Physiotherapi',
#   'is',
#   'locat',
#   'at',
#   'a',
#   'busi',
#   'commerci',
#   'region',
#   'on',
#   'the',
#   'NSW',
#   'Central',
#   'Coast',
#   'We',
#   'regard',
#   'ourselv',
#   'as',
#   'leader',
#   'in',
#   'the',
#   'manag',
#   'of',
#   'musculoskelet',
#   'disord',
#   'We',
#   'have',
#   'a',
#   'strong',
#   'relationship',
#   'with',
#   'local',
#   'GP',
#   'orthopaed',
#   'surgeon',
#   'sport',
#   'physician',
#   'repres',
#   'junior',
#   'rugbi',
#   'leagu',
#   'team',
#   'and',
#   'fulltim',
#   'danc',
#   'academi',
#   'The',
#   'practic',
#   'princip',
#   'is',
#   'an',
#   'APA',
#   'Titl',
#   'Musculoskelet',
#   'Physiotherapist'],
#  ['nan'],
#  ['Report',
#   'to',
#   'the',
#   'JLL',
#   'Global',
#   'Busi',
#   'Support',
#   'Manag',
#   'Canberra',
#   'the',
#   'Global',
#   'Properti',
#   'Manag',
#   'will',
#   'be',
#   'base',
#   'onsit',
#   'with',
#   'DFAT',
#   'in',
#   'Canberra',
#   'and',
#   'will',
#   'have',
#   'the',
#   'overal',
#   'respons',
#   'of',
#   'the',
#   'daytoday',
#   'manag',
#   'of',
#   'all',
#   'aspect',
#   'of',
#   'the',
#   'DFAT',
#   'Properti',
#   'and',
#   'Leas',
#   'Manag',
#   'function',
#   'They',
#   'will',
#   'ensur',
#   'all',
#   'properti',
#   'and',
#   'leas',
#   'data',
#   'is',
#   'complet',
#   'up',
#   'to',
#   'date',
#   'and',
#   'accur'],
#  ['Part',
#   'time',
#   'kitchenhand',
#   'need',
#   'at',
#   'Rozel',
#   'cafe',
#   'We',
#   'are',
#   'look',
#   'for',
#   'someon',
#   'who',
#   'ha',
#   'some',
#   'experi',
#   'we',
#   'are',
#   'will',
#   'to',
#   'train',
#   'the',
#   'right',
#   'person',
#   'to',
#   'help',
#   'with',
#   'food',
#   'prep',
#   'etc',
#   'English',
#   'is',
#   'a',
#   'must',
#   'no',
#   'short',
#   'term',
#   'travel',
#   'pleas',
#   'Weekend',
#   'work',
#   'and',
#   'some',
#   'week',
#   'day',
#   'Pleas',
#   'forward',
#   'email',
#   'to',
#   'k8com',
#   'click',
#   'to',
#   'reveal',
#   'or',
#   'call',
#   '5418',
#   'click',
#   'to',
#   'reveal',
#   'between',
#   '10am3pm',
#   'If',
#   'possibl',
#   'pleas',
#   'appli',
#   'in',
#   'person',
#   'with',
#   'your',
#   'resum',
#   'at',
#   '618',
#   'Darl',
#   'st',
#   'Rozel'],
#  ['nan'],
#  ['Look',
#   'for',
#   'someon',
#   'to',
#   'bolt',
#   'on',
#   'a',
#   'sign',
#   'to',
#   'the',
#   'front',
#   'of',
#   'our',
#   'build',
#   'in',
#   'Fitzroy',
#   'power',
#   'alreadi',
#   'there',
#   'Etc',
#   'just',
#   'need',
#   'to',
#   'be',
#   'lift',
#   'up',
#   'and',
#   'bolt',
#   'onto',
#   'second',
#   'stori',
#   'brick'],
#  ['To',
#   'support',
#   'our',
#   'Market',
#   'Cloud',
#   'strategi',
#   'we',
#   'need',
#   'an',
#   'Enterpris',
#   'Sale',
#   'Rep',
#   'to',
#   'drive',
#   'highvalu',
#   'market',
#   'softwar',
#   'sale',
#   'via',
#   'CMO',
#   'into',
#   'enterpris',
#   'custom',
#   'Whi',
#   'join',
#   'Oracl',
#   'We',
#   'deliv',
#   'on',
#   'our',
#   'promis',
#   'we',
#   'provid',
#   'a',
#   'stabl',
#   'base',
#   'for',
#   'our',
#   'employe',
#   'so',
#   'they',
#   'can',
#   'focu',
#   'on',
#   'sell',
#   'and',
#   'reward',
#   'them',
#   'huge',
#   'when',
#   'theyr',
#   'success',
#   'We',
#   'provid',
#   'extens',
#   'train',
#   'and',
#   'career',
#   'opportun',
#   'and',
#   'a',
#   'brand',
#   'profession',
#   'reput',
#   'within',
#   'our',
#   'custom',
#   'that',
#   'help',
#   'open',
#   'door',
#   'into',
#   'prospect',
#   'for',
#   'you',
#   'Were',
#   'grow',
#   'where',
#   'other',
#   'are',
#   'shrink',
#   'and',
#   'RD',
#   'is',
#   'a',
#   'big',
#   'invest',
#   'for',
#   'us',
#   'each',
#   'year',
#   'to',
#   'ensur',
#   'our',
#   'softwar',
#   'remain',
#   'current',
#   'and',
#   'innov',
#   'long',
#   'after',
#   'the',
#   'cool',
#   'compani',
#   'have',
#   'ceas',
#   'be',
#   'cool'],
#  ['Our',
#   'client',
#   'is',
#   'look',
#   'for',
#   'someon',
#   'to',
#   'join',
#   'their',
#   'cafe',
#   'as',
#   'a',
#   'full',
#   'time',
#   'barista',
#   'at',
#   'a',
#   'local',
#   'cafe',
#   'in',
#   'Ipswich',
#   'Must',
#   'be',
#   'friendli',
#   'and',
#   'be',
#   'abl',
#   'to',
#   'work',
#   'well',
#   'under',
#   'pressur'],
#  ['An',
#   'excit',
#   'opportun',
#   'ha',
#   'arisen',
#   'for',
#   'a',
#   'Commerci',
#   'Lawyer',
#   'IT',
#   'to',
#   'join',
#   'the',
#   'Woolworth',
#   'Legal',
#   'team',
#   'You',
#   'will',
#   'be',
#   'respons',
#   'for',
#   'advis',
#   'on',
#   'a',
#   'broad',
#   'rang',
#   'of',
#   'commerci',
#   'contract',
#   'with',
#   'a',
#   'weight',
#   'toward',
#   'technolog',
#   'matter',
#   'includ',
#   'softwar',
#   'licens',
#   'hardwar',
#   'procur',
#   'IT',
#   'consult',
#   'and',
#   'licens',
#   'Thi',
#   'is',
#   'an',
#   'outstand',
#   'opportun',
#   'to',
#   'use',
#   'your',
#   'commerci',
#   'acumen',
#   'by',
#   'provid',
#   'strateg',
#   'and',
#   'risk',
#   'balanc',
#   'legal',
#   'advic',
#   'across',
#   'a',
#   'number',
#   'of',
#   'jurisdict',
#   'and',
#   'divers',
#   'rang',
#   'of',
#   'busi',
#   'in',
#   'a',
#   'fast',
#   'pace',
#   'dynam',
#   'environ'],
#  ['Harvey',
#   'Norman',
#   'is',
#   'seek',
#   'an',
#   'enthusiast',
#   'and',
#   'motiv',
#   'Electr',
#   'Salesperson',
#   'for',
#   'the',
#   'McGrath',
#   'Hill',
#   'store',
#   'Thi',
#   'is',
#   'a',
#   'full',
#   'time',
#   'posit',
#   'work',
#   'on',
#   'a',
#   'rotat',
#   'roster',
#   'which',
#   'includ',
#   'weekend',
#   'work',
#   'and',
#   'late',
#   'night',
#   'trade',
#   'Immedi',
#   'start',
#   'is',
#   'avail'],
#  ['At',
#   'INPEX',
#   'youll',
#   'have',
#   'the',
#   'freedom',
#   'to',
#   'turn',
#   'your',
#   'idea',
#   'into',
#   'realiti',
#   'Youll',
#   'be',
#   'part',
#   'of',
#   'a',
#   'global',
#   'team',
#   'driven',
#   'to',
#   'conquer',
#   'the',
#   'challeng',
#   'present',
#   'by',
#   'worldlead',
#   'project',
#   'like',
#   'our',
#   'Ichthi',
#   'LNG',
#   'Project',
#   'Best',
#   'of',
#   'all',
#   'youll',
#   'discov',
#   'an',
#   'energi',
#   'infinit',
#   'more',
#   'valuabl',
#   'than',
#   'oil',
#   'and',
#   'ga',
#   'We',
#   'call',
#   'it',
#   'Will',
#   'Power'],
#  ['Our',
#   'client',
#   'is',
#   'a',
#   'leader',
#   'within',
#   'the',
#   'Poultri',
#   'Process',
#   'Industri',
#   'base',
#   'in',
#   'Sydney',
#   'West',
#   'who',
#   'is',
#   'current',
#   'seek',
#   'experienc',
#   'Poultri',
#   'Worker',
#   'to',
#   'join',
#   'a',
#   'fast',
#   'pace',
#   'night',
#   'crew'],
#  ['nan'],
#  ['Essenti',
#   'Servic',
#   'Offic',
#   'are',
#   'respons',
#   'for',
#   'the',
#   'mainten',
#   'of',
#   'power',
#   'water',
#   'sewerag',
#   'and',
#   'aircraft',
#   'land',
#   'area',
#   'in',
#   'our',
#   'remot',
#   'commun',
#   'Work',
#   'close',
#   'with',
#   'the',
#   'Team',
#   'Leader',
#   'Work',
#   'and',
#   'Council',
#   'Servic',
#   'Coordin',
#   'thi',
#   'posit',
#   'liais',
#   'with',
#   'Power',
#   'and',
#   'Water',
#   'provid',
#   'read',
#   'and',
#   'report',
#   'on',
#   'the',
#   'essenti',
#   'servic',
#   'in',
#   'the',
#   'commun'],
#  ['MR',
#   'TRUCK',
#   'DRIVER',
#   'REQUIR',
#   'BY',
#   'BUSI',
#   'RELOC',
#   'CO',
#   'FOR',
#   'CASUAL',
#   'REMOV',
#   'WORK',
#   'ON',
#   'WEEKDAY',
#   'AND',
#   'WEEKEND',
#   'AM',
#   'AND',
#   'PM',
#   'SHIFT'],
#  ['Our',
#   'client',
#   'is',
#   'a',
#   'one',
#   'of',
#   'the',
#   'largest',
#   'and',
#   'lead',
#   'wholesal',
#   'in',
#   'the',
#   'world',
#   'who',
#   'ha',
#   'a',
#   'strong',
#   'reput',
#   'for',
#   'provid',
#   'the',
#   'best',
#   'qualiti',
#   'tyre',
#   'and',
#   'tube',
#   'Current',
#   'they',
#   'requir',
#   'a',
#   'Deliveri',
#   'Driver',
#   'to',
#   'deliv',
#   'good',
#   'to',
#   'local',
#   'client',
#   'within',
#   'the',
#   'northern',
#   'suburb',
#   'of',
#   'Melbourn',
#   'and',
#   'assist',
#   'the',
#   'warehous',
#   'team',
#   'on',
#   'occas']]

# %%
joinedabstracts = []
for wordlist in tokenisedtext:
    #print(wordlist)
    backtogether = ''.join([word+' ' for word in wordlist])
    #joinedwords.join([word+' ' for word in wordlist])
    #print(backtogether)
    joinedabstracts.append(backtogether)    
    
print(joinedabstracts[0:21])
# Out:
# ['We are look for suitabl applic to fill the posit of Delicatessen Assist Manag and Delicatessen Supervisor at our Edmonton store The applic must have at least 1 year manag supervisori experi in a larg Delicatessen Depart includ strong team leadership qualiti ', 'Bricki Labour requir for a small team work with the owner A good environ where we are happi to guid and teach our labour All our Bricklay have first been labour and treat them well Must have a white card ABN work boot and some experi To discuss the posit call or text Megan on 6344 click to reveal or Mark 6344 click to reveal ', 'We are look for someon to take up to the next level and who ha previous work as a Head Chef in a pub environ You will have a strong passion for produc amaz pub grub with present to match ', 'We are seek experienc conveyanc settlement clerk who are keen to take on a new challeng in their career Step away from file manag complet you will have the opportun to use your peopl skill to hit the road and build relationship with a number of other profession in the industri ', 'Thi is fundament a nut and bolt role that would suit a systemat driven individu who strive on logist and organis Report to the GM of the venu the day to day duti will requir an analyt mind someon who also thrive on plan and troubleshoot With the abil to multitask and work within a tight timefram you will be someon who is ultim highli motiv and love challeng ', 'Due to an intern promot our client a wellestablish organis within the construct industri is current seek an experienc Transport Schedul Coordin from the Construct Concret Industri to join their team on a perman full time basi ', 'nan ', 'Due to demand the compani ha an amaz opportun for an experi Bar Supervisor look to take the next step in their career Locat in one of Sydney premier and busiest indoor outdoor waterfront locat and part of a lead hospit group which boast multipl venu thi opportun will not last long ', 'If you are someon that strive to put a smile on a resid face make a real differ to their qualiti of life make the most of your passion by join us at UnitingCar Age NSWACT We are keen to provid you with a platform to shineWHO WE AREUnitingCar Age NSWACT the age care ministri of the Unit Church a Servic Group of UnitingCar NSWACT is the singl largest notforprofit provid of age care servic in NSW the ACT We are an industri leaderEveryday ha mean when you work for us Your work make a real differenceBi enrich the live of those we serv we add valu to the experi of life As an Industri Leader we valu our staff and our client We are bold imagin respect and compassion becaus that is what give us the edg and satisfact in what we doJOIN OUR DYNAM TEAMMirinjani is now seek dedic Care Servic Employe to join their dynam team in Weston ACT on a casual basi Success candid will be requir to work across all support streamsW want a care worker who is passion genuin and commit to provid except care You will work collabor as a care team member to deliv a personcentr care that enhanc the resid wellb and is inclus of their physic psycholog social and spiritu qualiti in order to facilit selfdetermin capac and resili as well as improv social engag and qualiti of life for the resid and to incorpor the deliveri of person hygien nutrit and hydrat contin care and leisur and lifestyl activitiesTo succeed in thi role you will meet the criteria belowEssenti Criteria Demonstr a genuin interest in Age Care Nurs Strong commun and interperson skill particularli with age person rel and other health profession Knowledg and understand of Work Health and Safeti WH and risk manag practic Abil to work in a team environ or independ Abil to be proactiv flexibl and take initi in the work environ Commit to ongo profession developmentDesir Criteria An awar of the Age Care Accredit Process Previou experi in age care person care work Basic comput literaci Certif III in Age Care Work Commun Servic or equival Current First Aid CertificateApplic must be in a po ...

# %%
cluster_texts(joinedabstracts[0:50])
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:
# applic
# team
# experi
# posit
# look
# work
# thi
# requir
# role
# defaultdict(list,
#             {0: [11, 15, 16, 24, 30],
#              1: [3, 6, 10, 13, 31, 32, 34, 35, 37, 42, 45, 46, 49],
#              2: [5, 14, 22, 47],
#              3: [2, 23, 36],
#              4: [28, 43],
#              5: [4, 9, 17, 19, 20, 26, 29, 38],
#              6: [7, 12, 18],
#              7: [8, 33, 40, 44],
#              8: [1, 25, 27, 41],
#              9: [0, 21, 39, 48]})

# %%
joinedabstracts[:4]
# Out:
# ['We are look for suitabl applic to fill the posit of Delicatessen Assist Manag and Delicatessen Supervisor at our Edmonton store The applic must have at least 1 year manag supervisori experi in a larg Delicatessen Depart includ strong team leadership qualiti ',
#  'Bricki Labour requir for a small team work with the owner A good environ where we are happi to guid and teach our labour All our Bricklay have first been labour and treat them well Must have a white card ABN work boot and some experi To discuss the posit call or text Megan on 6344 click to reveal or Mark 6344 click to reveal ',
#  'We are look for someon to take up to the next level and who ha previous work as a Head Chef in a pub environ You will have a strong passion for produc amaz pub grub with present to match ',
#  'We are seek experienc conveyanc settlement clerk who are keen to take on a new challeng in their career Step away from file manag complet you will have the opportun to use your peopl skill to hit the road and build relationship with a number of other profession in the industri ']

# %%
ls ..

# %%
import pandas as pd

data = pd.read_csv('../Jobsnew.csv',delimiter='\t',encoding='latin-1')
data

# %%
data['tokenise'] = [process_text(str(a)) for a in data.abstract.tolist()]

# %%
cluster_texts(data.tokenise[0])

# %%
mylist = ['hello','how','wre', 'you']

# %%
new_bag = ''

new_bag.join([x+' ' for x in mylist])

# %%
new_bag
